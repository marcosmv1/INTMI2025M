# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosmv1/INTMI2025M/blob/main/Marcos_Vinicius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #algoritimo e lógica de programação

# %% [markdown]
# ##variáveis

# %%
a = 10
b = 15
print(a+b)
# Out:
# 25

# %% [markdown]
# ##Tipos De Dados
#
# int - inteiro - para números inteiros
#
# float - flutuante - para números com vírgula
#
# str - string - para palavras e textos
#
# bool - booleano - para verdadeiro e falso (binário) - true ou false

# %%
x = int(input("digite um número: "))
y = float(input("digite um número com vírgula: "))
z = str(input("digite um texto: "))
w = bool(input("digite um valor binário: "))
# Out:
# digite um número: 15
# digite um número com vírgula: 1.5
# digite um texto: Uma palavra
# digite um valor binário: True

# %%
print(x)
print(y)
print(z)
print(w)
# Out:
# 15
# 1.5
# Uma palavra
# True

# %%
print("este é um número inteiro: " , x," e o próximo é um flutuante: ", y)
# Out:
# este é um número inteiro:  15  e o próximo é um flutuante:  1.5

# %% [markdown]
# ##Operadores
#
# adição +
#
#
# subtração -
#
#
# multiplicação *
#
#
# divisão /
#
# Potência ^
#
# Resto da divisão %

# %% [markdown]
# 1 - crie um algoritmo que receba 2 números, em variáveis diferentes (num1 - num2), depois faça as 4 operações com esses 2 números. e mostre o resultado na tela.

# %%
num1 = int(input("digite um número: "))
num2 = int(input("digite outro número: "))
print("a soma é ", num1+num2)
print("a subtração é ", num1-num2)
print("a multiplicação é: ", num1*num2)
print("a divisão é: ", num1/num2)
# Out:
# digite um número: 1
# digite outro número: 15000
# a soma é  15001
# a subtração é  -14999
# a multiplicação é:  15000
# a divisão é:  6.666666666666667e-05

# %%
print("a soma é ", num1+num2)
print("a subtração é ", num1-num2)
print("a multiplicação é: ", num1*num2)
print("a divisão é: ", num1/num2)

# %%
print(f"O primeiro número é {num1} e o segundo número é {num2}")
# Out:
# O primeiro número é 1 e o segundo número é 15000

# %%
2 - Crie um algoritmo que receba o nome do usuário na variável (nome) , e a idade na variável (idade) , e depois mostre na tela a seguinte frase:

Olá, meu nome é (nome) e eu tenho (idade) anos!

# %%
str(input("nome: "))
str(input("idade: "))

str(input("nome: "))
# Out:
# nome: Marcos
# idade: 844
# '844'
